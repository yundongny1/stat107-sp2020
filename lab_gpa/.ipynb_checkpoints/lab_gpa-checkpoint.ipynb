# %% [markdown]
# # Your Grades and GPA at Illinois!
#
# In this lab, you will explore the GPA dataset and find out about the easiest, hardest, and most popular courses at Illinois!

# %% [markdown]
# # Part 0: Your Group!
#
# Edit the next Python cell to add information about who you're working within your lab section:

# %%
# First, meet your CAs and TA if you haven't already!
# ...first name is enough, we'll know who they are! :)
ta_name = "ANKU"
ca1_name = "Jasmine"
ca2_name = "Dean"


# Also, make sure to meet your team for this lab! Find out their name, what major they're in,
# and learn something new about them that you never knew before!
partner1_name = "Cara Sarver"
partner1_netid = "csarver2"
partner1_major = "CHBE"
partner1_qotd_answer = "Rain"

partner2_name = "serena"
partner2_netid = "zhuouyue3"
partner2_major = "math"
partner2_qotd_answer = "BBQ"

partner3_name = ""
partner3_netid = ""
partner3_major = ""
partner3_qotd_answer = ""

partner4_name = ""
partner4_netid = ""
partner4_major = ""
partner4_qotd_answer = ""

# %% [markdown]
# ## Part 0.5 | Loading the Dataset
#
# For the first part of our lab, we'll be using the GPA dataset we saw in class.
#
# You can download the dataset by following to following link to the github storing the dataset: https://raw.githubusercontent.com/wadefagen/datasets/master/gpa/uiuc-gpa-dataset.csv
#
# To download this file, you will want to **right click** and click **Save As**.

# %% [markdown]
# ## Part 1 | Finding Total GPAs
#
# Add two new columns, `Total Students` and `Average GPA`, that compute the total number of students in each course and the average weighted GPA for each course.
#
# You should not include students with a `W` in either column and feel free to add other columns to help you out!

# %%
import pandas as pd
df = pd.read_csv("uiuc-gpa-dataset.csv")

df["Total Students"] = (df["A+"]) + (df["A"]) + (df["A-"]) + (df["B+"]) + (df["B"]) + (df["B-"]) + (df["C+"]) + (df["C"]) + (df["C-"]) + (df["D+"]) + (df["D"]) + (df["D-"]) + (df["F"])
df["Total GPA"] = (df["A+"] * 4) + (df["A"] * 4) + (df["A-"] * 3.67) + (df["B+"] * 3.33) + (df["B"] * 3) + (df["B-"] * 2.67) + (df["C+"] * 2.33) + (df["C"] * 2) + (df["C-"] * 1.67) + (df["D+"] * 1.33) + (df["D"] * 1) + (df["D-"] * .67) + (df["F"] * 0)
df["Average GPA"] = (((df["A+"] * 4) + (df["A"] * 4) + (df["A-"] * 3.67) + (df["B+"] * 3.33) + (df["B"] * 3) + (df["B-"] * 2.67) + (df["C+"] * 2.33) + (df["C"] * 2) + (df["C-"] * 1.67) + (df["D+"] * 1.33) + (df["D"] * 1) + (df["D-"] * .67) + (df["F"] * 0)) / df["Total Students"])

# %%
## == TEST CASES for Puzzle 1 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check you previous cell, make changes, and RE-RUN your code and then this cell.

assert(df[
  (df["YearTerm"] == "2010-su") & \
  (df["Subject"] == "STAT") & \
  (df["Number"] == 410) \
]["Total Students"].sum() == 31), "It appears your \"Total Students\" column is incorrect."

assert(df[
  (df["YearTerm"] == "2018-fa") & \
  (df["Subject"] == "CS") & \
  (df["Number"] == 225) \
]["Total Students"].sum() == 697), "It appears your \"Total Students\" column is incorrect."

assert( abs(df[
  (df["YearTerm"] == "2018-fa") & \
  (df["Subject"] == "STAT") & \
  (df["Number"] == 100) \
]["Average GPA"].mean() - 3.247) < 0.01), "It appears your \"Average GPA\" column is incorrect."

# %% [markdown]
# ## Part 2 | Finding the easiest and hardest courses
#
# ### Puzzle 2.1: Hardest Courses in the Dataset
#
# Using functions you already know, find the **30 hardest courses** at Illinois based on their "Average GPA".

# %%
df_hardestCourses = df.nsmallest(30, "Average GPA")
df_hardestCourses
# Out:
#        Year    Term YearTerm Subject  Number                   Course Title  \
# 4111   2018    Fall  2018-fa     LER     120    Contemporary Labor Problems
# 16583  2016  Spring  2016-sp     LER     100  Introduction to Labor Studies
# 24396  2014    Fall  2014-fa     LER     120    Contemporary Labor Problems
# 26664  2014  Spring  2014-sp     LER     120    Contemporary Labor Problems
# 29461  2013    Fall  2013-fa    MATH       2           Introductory Algebra
# 26739  2014  Spring  2014-sp    MATH     220                       Calculus
# 1407   2019  Spring  2019-sp     LER     100  Introduction to Labor Studies
# 14311  2016    Fall  2016-fa     LER     120    Contemporary Labor Problems
# 14579  2016    Fall  2016-fa     MCB     245     Human Anat & Physiol Lab I
# 24443  2014    Fall  2014-fa     LLS     296  Bilingual US Latina/o Culture
# 24607  2014    Fall  2014-fa     MCB     245     Human Anat & Physiol Lab I
# 11512  2017  Spring  2017-sp     LER     100  Introduction to Labor Studies
# 5462   2018  Spring  2018-sp    CHEM     101         Introductory Chemistry
# 14307  2016    Fall  2016-fa     LER     100  Introduction to Labor Studies
# 14310  2016    Fall  2016-fa     LER     110     Labor and Social Movements
# 39931  2011  Spring  2011-sp    MATH     115       Preparation for Calculus
# 14570  2016    Fall  2016-fa     MCB     245     Human Anat & Physiol Lab I
# 39867  2011  Spring  2011-sp     LER     100  Introduction to Labor Studies
# 26259  2014  Spring  2014-sp    ENGL     274          Contemporary Classics
# 19374  2015    Fall  2015-fa    MATH     181           A Mathematical World
# 4321   2018    Fall  2018-fa     MCB     245     Human Anat & Physiol Lab I
# 14575  2016    Fall  2016-fa     MCB     245     Human Anat & Physiol Lab I
# 38279  2011    Fall  2011-fa     TAM     251   Introductory Solid Mechanics
# 43487  2011  Summer  2011-su     TAM     251   Introductory Solid Mechanics
# 24192  2014    Fall  2014-fa      IE     300               Analysis of Data
# 31769  2013  Spring  2013-sp    MATH     115       Preparation for Calculus
# 2244   2019  Summer  2019-su    CHEM     102            General Chemistry I
# 37392  2011    Fall  2011-fa     LER     110     Labor and Social Movements
# 42600  2011  Summer  2011-su     LER     110     Labor and Social Movements
# 11517  2017  Spring  2017-sp     LER     110     Labor and Social Movements
#
#        A+  A  A-  B+  ...  C-  D+   D  D-   F  W    Primary Instructor  \
# 4111    0  0   1   2  ...   2   1   1   0  15  0           Taylor, Don
# 16583   0  1   0   1  ...   1   1   1   1  10  0      Hawking, Carol J
# 24396   0  4   0   1  ...   1   0   1   0  15  1     Hershfield, David
# 26664   0  1   3   0  ...   0   0   0   2  11  0     Cohen, Margaret L
# 29461   0  0   0   0  ...   5   3   3   2   5  3   Aydin-Mullen, Yelda
# 26739   0  3   0   0  ...   0   2   1   0  11  1    Gilbert, Rebekah A
# 1407    0  2   1   2  ...   0   0   2   1   9  0     Cohen, Margaret L
# 14311   0  2   2   1  ...   1   2   1   2   8  2     Hershfield, David
# 14579   0  0   0   0  ...   4   1   2   0   6  1      Swigart, James P
# 24443   3  1   0   1  ...   1   1   0   2  11  1     Romero, Rolando J
# 24607   0  0   1   0  ...   3   5   1   1   5  0      Swigart, James P
# 11512   0  2   1   1  ...   2   0   1   0   9  0         Ashby, Steven
# 5462    1  5   8   1  ...   9  11  23  10  26  7     Decoste, Donald J
# 14307   0  2   1   2  ...   2   0   1   1  10  0    Stewart, Beverly L
# 14310   0  4   2   0  ...   1   0   1   4   8  0         Ashby, Steven
# 39931   1  4   2   1  ...   0   9  11   2  18  0       Carty, Thomas E
# 14570   0  0   1   1  ...   3   3   4   1   4  2      Swigart, James P
# 39867   2  1   0   2  ...   2   0   0   1   9  2       Konopacki, Mike
# 26259   0  1   3   0  ...   2   1   0   0   8  1        Hutner, Gordon
# 19374   1  3   0   2  ...   1   1   1   1   8  0         Loeb, Sarah J
# 4321    0  0   1   2  ...   1   0   1   1   7  0      Swigart, James P
# 14575   0  0   1   2  ...   1   1   1   3   6  0      Swigart, James P
# 38279   1  0   4   2  ...   3   6  23   9  11  0  Starzewski, Martin O
# 43487   1  0   4   2  ...   3   6  23   9  11  0  Starzewski, Martin O
# 24192   4  1   3   1  ...  10   9   8   2  14  4        Tursun, Umit D
# 31769   0  3   5   3  ...   6   6   3   6  26  4   Lansing, Jennifer L
# 2244    0  2   2   4  ...   3   3   3   9  10  6       Marville, Kelly
# 37392   0  3   0   1  ...   3   0   3   0   7  0         Saute, Robert
# 42600   0  3   0   1  ...   3   0   3   0   7  0         Saute, Robert
# 11517   0  3   2   0  ...   0   0   1   0  12  2    Schiavone, Michael
#
#        Total Students  Total GPA  Average GPA
# 4111               28      32.00     1.142857
# 16583              24      31.67     1.319583
# 24396              30      42.00     1.400000
# 26664              25      35.69     1.427600
# 29461              31      44.35     1.430645
# 26739              28      41.33     1.476071
# 1407               21      31.33     1.491905
# 14311              22      33.34     1.515455
# 14579              23      35.01     1.522174
# 24443              27      42.35     1.568519
# 24607              25      39.67     1.586800
# 11512              23      36.68     1.594783
# 5462              132     211.05     1.598864
# 14307              27      43.34     1.605185
# 14310              25      40.36     1.614400
# 39931              71     114.97     1.619296
# 14570              25      40.67     1.626800
# 39867              22      36.00     1.636364
# 26259              21      34.68     1.651429
# 19374              23      37.99     1.651739
# 4321               23      38.00     1.652174
# 14575              26      43.01     1.654231
# 38279             102     169.03     1.657157
# 43487             102     169.03     1.657157
# 24192              75     124.68     1.662400
# 31769              96     159.69     1.663438
# 2244               52      86.69     1.667115
# 37392              24      40.33     1.680417
# 42600              24      40.33     1.680417
# 11517              29      49.35     1.701724
#
# [30 rows x 24 columns]

# %% [markdown]
# ### Puzzle 2.2: Hardest Courses in 2019
#
# Find the **30 hardest courses in 2019** at Illinois based on their "Average GPA".

# %%
df_hardestCourses_2019  = df[df["Year"] == 2019].nsmallest(30, "Average GPA")
df_hardestCourses_2019
# Out:
#       Year    Term YearTerm Subject  Number                    Course Title  \
# 1407  2019  Spring  2019-sp     LER     100   Introduction to Labor Studies
# 2244  2019  Summer  2019-su    CHEM     102             General Chemistry I
# 1410  2019  Spring  2019-sp     LER     120     Contemporary Labor Problems
# 1487  2019  Spring  2019-sp    MATH     112                         Algebra
# 2376  2019  Summer  2019-su    SPAN     141        Intro to Spanish Grammar
# 918   2019  Spring  2019-sp    ECON     302      Inter Microeconomic Theory
# 526   2019  Spring  2019-sp    CHEM     232  Elementary Organic Chemistry I
# 1498  2019  Spring  2019-sp    MATH     220                        Calculus
# 917   2019  Spring  2019-sp    ECON     302      Inter Microeconomic Theory
# 1839  2019  Spring  2019-sp    PSYC     100                     Intro Psych
# 2355  2019  Summer  2019-su    PSYC     245            Industrial Org Psych
# 2331  2019  Summer  2019-su     MCB     245      Human Anat & Physiol Lab I
# 1492  2019  Spring  2019-sp    MATH     124              Finite Mathematics
# 510   2019  Spring  2019-sp    CHEM     102             General Chemistry I
# 2329  2019  Summer  2019-su    MATH     417       Intro to Abstract Algebra
# 1499  2019  Spring  2019-sp    MATH     220                        Calculus
# 509   2019  Spring  2019-sp    CHEM     102             General Chemistry I
# 916   2019  Spring  2019-sp    ECON     302      Inter Microeconomic Theory
# 1844  2019  Spring  2019-sp    PSYC     201           Intro to Social Psych
# 2349  2019  Summer  2019-su    PSYC     201           Intro to Social Psych
# 1435  2019  Spring  2019-sp    LING     301              Elements of Syntax
# 1665  2019  Spring  2019-sp      ME     330           Engineering Materials
# 1594  2019  Spring  2019-sp     MCB     247     Human Anat & Physiol Lab II
# 1663  2019  Spring  2019-sp      ME     320                   Heat Transfer
# 2373  2019  Summer  2019-su    SPAN     101            Elementary Spanish I
# 127   2019  Spring  2019-sp     ACE     100      Agr Cons and Resource Econ
# 1349  2019  Spring  2019-sp     KIN     140    Social Sci of Human Movement
# 1290  2019  Spring  2019-sp    INFO     202        Social Aspects Info Tech
# 1598  2019  Spring  2019-sp     MCB     247     Human Anat & Physiol Lab II
# 1600  2019  Spring  2019-sp     MCB     247     Human Anat & Physiol Lab II
#
#       A+   A  A-  B+  ...  C-  D+   D  D-   F  W     Primary Instructor  \
# 1407   0   2   1   2  ...   0   0   2   1   9  0      Cohen, Margaret L
# 2244   0   2   2   4  ...   3   3   3   9  10  6        Marville, Kelly
# 1410   1   3   1   0  ...   2   0   2   0   7  0         King, Judith L
# 1487   1   4   4   2  ...   3   3   3   2  12  0          Reddy, Alison
# 2376   0   1   0   2  ...   3   1   1   0   4  0     Carollo, Brenden C
# 918    2   0   3   2  ...   3   2   4   1   5  2       Buckley, Bryan D
# 526    2   1   1   2  ...   1   1   7   3   3  1          Kell, David A
# 1498  11  21   2   7  ...  12  12  23   5  47  3       Murphy, Robert F
# 917    2   2   2   1  ...   2   4   3   3   6  0       Buckley, Bryan D
# 1839   0   0   1   1  ...   3   1   4   0   4  0         Travis, Lisa L
# 2355   1   0   2   2  ...   2   1   1   0   8  0  Shenouda, Christine K
# 2331   0   1   0   2  ...   0   1   2   0   5  1       Swigart, James P
# 1492   0   3   1   2  ...   3   1   0   3   3  0          Kim, Heejoung
# 510    3  10   6   4  ...   8   4   4  11  11  5        Marville, Kelly
# 2329   2   1   1   2  ...   2   0   2   1   4  1        McCarthy, Randy
# 1499   5  26  13   5  ...  15   5  19   4  35  5       Murphy, Robert F
# 509    6  16  11  20  ...  19  18  25  29  12  4        Marville, Kelly
# 916    1   2   3   2  ...   4   0   1   3   5  0       Buckley, Bryan D
# 1844   1   3   3   1  ...   3   1   2   0   6  0    Albarracin, Dolores
# 2349   2   2   3   4  ...   0   0   1   1   8  1  Shenouda, Christine K
# 1435   7   2   3   2  ...   1   3   2   1   8  1       Green, Jeffrey J
# 1665   0   5   1   3  ...   3   0   7   2   3  0        King, William P
# 1594   2   0   3   1  ...   2   3   3   0   2  2       Swigart, James P
# 1663   1   2   4   3  ...   0   3   0   0   6  1     Pearlstein, Arne J
# 2373   3   2   3   0  ...   0   2   1   2   4  0       Bandin, Yvette A
# 127    0   2   2   2  ...   2   2   2   1   1  1      Gundersen, Lisa C
# 1349   0   1   8  12  ...  17   4   3   4   7  0     Pindus, Dominika M
# 1290   2   3   6   1  ...   1   7   1   1   7  0        Kendall, Lori S
# 1598   0   2   3   2  ...   2   2   0   2   3  0       Swigart, James P
# 1600   0   0   3   1  ...   5   0   1   1   1  0       Swigart, James P
#
#       Total Students  Total GPA  Average GPA
# 1407              21      31.33     1.491905
# 2244              52      86.69     1.667115
# 1410              22      39.68     1.803636
# 1487              44      82.35     1.871591
# 2376              21      39.32     1.872381
# 918               32      60.01     1.875313
# 526               28      52.67     1.881071
# 1498             218     414.69     1.902248
# 917               37      70.68     1.910270
# 1839              34      65.68     1.931765
# 2355              31      60.67     1.957097
# 2331              23      45.99     1.999565
# 1492              22      45.34     2.060909
# 510               86     179.40     2.086047
# 2329              21      44.01     2.095714
# 1499             208     437.41     2.102933
# 509              252     530.09     2.103532
# 916               31      65.68     2.118710
# 1844              34      73.02     2.147647
# 2349              29      63.00     2.172414
# 1435              34      73.99     2.176176
# 1665              55     122.03     2.218727
# 1594              27      60.01     2.222593
# 1663              33      73.35     2.222727
# 2373              21      46.68     2.222857
# 127               25      55.67     2.226800
# 1349             110     246.39     2.239909
# 1290              60     135.00     2.250000
# 1598              28      63.00     2.250000
# 1600              24      54.03     2.251250
#
# [30 rows x 24 columns]

# %% [markdown]
# ### Puzzle 2.3: Easiest Courses in 2019
#
# Find the **30 easiest courses in 2019** at Illinois based on their "Average GPA".

# %%
df_easiestCourses_2019 = df[df["Year"] == 2019].nlargest(30, "Average GPA")
df_easiestCourses_2019
# Out:
#       Year    Term YearTerm Subject  Number                    Course Title  \
# 2311  2019  Summer  2019-su      IS     532    Theory & Pract Data Cleaning
# 595   2019  Spring  2019-sp      CI     473           Disciplinary Literacy
# 1118  2019  Spring  2019-sp    FSHN     502        Advanced Sensory Science
# 1980  2019  Spring  2019-sp     SHS     352      Hearing Health and Society
# 1340  2019  Spring  2019-sp     KIN     104              Skating Activities
# 1911  2019  Spring  2019-sp     REL     208   Cultures & Lits of South Asia
# 2362  2019  Summer  2019-su     SBC     509      Strategic Media Management
# 1418  2019  Spring  2019-sp     LER     590      Gov't Reg & Employment Law
# 2023  2019  Spring  2019-sp    SOCW     297       Asian Families in America
# 2298  2019  Summer  2019-su    FSHN     595  Nutrition for Health & Fitness
# 1310  2019  Spring  2019-sp      IS     543     Sociotechnical Info Systems
# 1302  2019  Spring  2019-sp      IS     501             Info Org and Access
# 229   2019  Spring  2019-sp    ANSC     103       Working With Farm Animals
# 416   2019  Spring  2019-sp    BADM     590              Strategic Sourcing
# 2308  2019  Summer  2019-su      IB     533   Human Genome & Bioinformatics
# 2201  2019  Summer  2019-su    ACCY     593              Prof Soft Skills I
# 367   2019  Spring  2019-sp    BADM     445       Small Business Consulting
# 1343  2019  Spring  2019-sp     KIN     109           Team Sport Activities
# 1717  2019  Spring  2019-sp     MUS     450       U of I Symphony Orchestra
# 1722  2019  Spring  2019-sp    NPRE     199           Undergraduate Seminar
# 1311  2019  Spring  2019-sp      IS     543     Sociotechnical Info Systems
# 777   2019  Spring  2019-sp     ECE     206    Electrical & Electronics Lab
# 2309  2019  Summer  2019-su      IS     502      Libraries Info and Society
# 989   2019  Spring  2019-sp     ENG     398         ELA Leadership Training
# 2107  2019  Spring  2019-sp    STAT     511      Mathematical Statistics II
# 344   2019  Spring  2019-sp    BADM     350  IT for Networked Organizations
# 491   2019  Spring  2019-sp     CEE     598   Building Information Modeling
# 1308  2019  Spring  2019-sp      IS     508          Collection Development
# 123   2019  Spring  2019-sp    ACCY     575     Data Analytics Apps in ACCY
# 1268  2019  Spring  2019-sp      IB     536            Evolutionary Biology
#
#        A+   A  A-  B+  ...  C-  D+  D  D-  F  W         Primary Instructor  \
# 2311  266  18   1   0  ...   0   0  0   0  0  0        Ludaescher, Bertram
# 595     0  94   2   1  ...   0   0  0   0  0  0           Filkins, Scott R
# 1118   34   3   0   1  ...   0   0  0   0  0  0              Lee, Soo-Yeun
# 1980    0  50   0   0  ...   0   0  0   0  0  0          Chambers, Ronny D
# 1340    0  49   0   0  ...   0   0  0   0  0  1              Park, Doo Jae
# 1911    0  46   0   0  ...   0   0  0   0  0  0              Mehta, Rini B
# 2362   22  17   0   0  ...   0   0  0   0  0  1                Yao, Mike Z
# 1418    1  36   1   1  ...   0   0  0   0  0  0           Leroy, Michael H
# 2023    0  38   0   0  ...   0   0  0   0  0  0          Balgopal, Anita A
# 2298    0  38   0   0  ...   0   0  0   0  0  0           Kundrat, Susan M
# 1310    0  62   1   0  ...   0   0  0   0  0  0          LaLone, Nicolas J
# 1302    0  33   1   1  ...   0   0  0   0  0  0             Smith, Linda C
# 229     0  56   0   1  ...   0   0  0   0  0  0            Parsons, Carl M
# 416    25  16   2   1  ...   0   0  0   0  0  0             Liang, Hongyan
# 2308   18   3   0   1  ...   0   0  0   0  0  0         Manaster, Joanne L
# 2201    0  60   0   0  ...   0   0  0   0  0  0        Reierson, Timothy J
# 367     0  29   0   0  ...   0   0  0   0  0  0           Kurtz, Jeffrey M
# 1343    0  28   0   0  ...   0   0  0   0  0  0          Morales, Dakota G
# 1717    0  33   1   0  ...   0   0  0   0  0  0       Schleicher, Donald J
# 1722    1  31   0   2  ...   0   0  0   0  0  0          Stubbins, James F
# 1311    0  48   0   0  ...   0   0  0   0  0  0          LaLone, Nicolas J
# 777     4  24   2   1  ...   0   0  0   0  0  0  Radhakrishnan, Chandrasek
# 2309    0  29   0   0  ...   0   0  0   0  0  0           Williams, DeAnza
# 989     0  34   2   0  ...   0   0  0   0  0  0         Forman, Gretchen M
# 2107    5  23   0   0  ...   0   0  0   0  0  0                Chen, Yuguo
# 344     0  59   3   0  ...   0   0  0   0  0  0          Nelson, Matthew L
# 491    25  60   5   0  ...   0   0  0   0  0  0       Golparvar Fard, Mani
# 1308    0  31   3   1  ...   0   0  0   0  0  0      Holba Puacz, Jeanne T
# 123     6  27   1   0  ...   0   0  0   0  0  0           Hobson, Jessen L
# 1268   21   4   2   1  ...   0   0  0   0  0  0          Birdsley, Jeffrey
#
#       Total Students  Total GPA  Average GPA
# 2311             286    1142.67     3.995350
# 595               97     386.67     3.986289
# 1118              38     151.33     3.982368
# 1980              51     203.00     3.980392
# 1340              50     199.00     3.980000
# 1911              47     187.00     3.978723
# 2362              40     159.00     3.975000
# 1418              39     155.00     3.974359
# 2023              39     155.00     3.974359
# 2298              39     155.00     3.974359
# 1310              64     254.34     3.974062
# 1302              35     139.00     3.971429
# 229               58     230.33     3.971207
# 416               44     174.67     3.969773
# 2308              22      87.33     3.969545
# 2201              61     242.00     3.967213
# 367               30     119.00     3.966667
# 1343              29     115.00     3.965517
# 1717              35     138.67     3.962000
# 1722              34     134.66     3.960588
# 1311              50     198.00     3.960000
# 777               31     122.67     3.957097
# 2309              30     118.67     3.955667
# 989               37     146.34     3.955135
# 2107              29     114.67     3.954138
# 344               64     253.01     3.953281
# 491               92     363.68     3.953043
# 1308              35     138.34     3.952571
# 123               35     138.34     3.952571
# 1268              28     110.67     3.952500
#
# [30 rows x 24 columns]

# %%
## == TEST CASES for Puzzle 2 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error or output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, RE-RUN your code, and then RE-RUN this cell.

assert( len(df_hardestCourses) == 30 ), "You should only have the 30 hardest courses."
assert( abs(df_hardestCourses["Average GPA"].mean() - 1.58) < 0.01 ), "Are you sure you have the 30 hardest courses?"

assert( len(df_hardestCourses_2019) == 30 ), "You should only have the 30 hardest courses in 2019."
assert( abs(df_hardestCourses_2019["Average GPA"].mean() - 2.04) < 0.01 ), "Are you sure you have the 30 hardest courses of 2019?"

assert( len(df_easiestCourses_2019) == 30 ), "You should only have the 30 easiest courses in 2019."
assert( abs(df_easiestCourses_2019["Average GPA"].mean() - 3.97) < 0.01 ), "Are you sure you have the 30 easiest courses of 2019?"

# %% [markdown]
# ## Puzzle 3: Finding Data on  Every Subject
#
# ### Puzzle 3.1: Total Grades Given in Each Subject
#
# Using `groupby` and `agg`, find the total number of each grade (eg: "A+"s, "A"s, "A-"s, etc.) for every subject in the DataFrame `df_grouped_subject`.

# %%
group = df.groupby("Subject")

df_grouped_subject = group.agg("sum").reset_index()
df_grouped_subject
# Out:
#     Subject     Year  Number    A+      A     A-     B+      B    B-    C+  \
# 0       AAS   314168   20114   592   1787    755    471    446   222   121
# 1       ABE   239706   39978   267   2270    748    650    851   226   121
# 2      ACCY  4051001  737270  6041  19837  13746  13389  12065  5064  2409
# 3       ACE  1585229  213623  2466  11620   4550   3898   6123  2375  1484
# 4      ACES   249729   14464   609   1743    232     90    240    59    59
# ..      ...      ...     ...   ...    ...    ...    ...    ...   ...   ...
# 156      UP   529757   96374   958   3203   1884   1128   1265   449   227
# 157      VB     8040    2489     0    212      6      6    120     1     0
# 158     VCM    74447   24157   302   1321     29     49   1036    20    18
# 159      VM   169227   51001     0   1619      8      0   5283     1     0
# 160    YDSH    24157    3340    38     76     79     30     40    11     6
#
#         C   C-   D+    D   D-    F    W  Total Students  Total GPA  \
# 0     111   45   26   28   18   58   24            4680   16439.74
# 1     163   46   16   39    5   43   13            5445   18962.46
# 2    1852  918  208  600  136  453  227           76718  260078.86
# 3    2025  692  332  584  186  494   95           36829  120546.63
# 4      70   20   11   25    6   62    6            3226   11791.19
# ..    ...  ...  ...  ...  ...  ...  ...             ...        ...
# 156   267  108   34   64   39  124   37            9750   33686.97
# 157    40    0    0    2    0    0    0             387    1334.67
# 158   337    1    1   41    0    1    0            3156   10682.94
# 159  3086    0    0  283    0    8    8           10288   28812.03
# 160     4    2    0    1    2    5    3             294    1022.86
#
#      Average GPA
# 0     546.984281
# 1     413.540485
# 2    6796.991258
# 3    2584.602275
# 4     456.138891
# ..           ...
# 156   917.539459
# 157    13.974534
# 158   128.099232
# 159   238.209547
# 160    41.746684
#
# [161 rows x 20 columns]

# %%
## == TEST CASES for Puzzle 3.1 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, RE-RUN your code, and then RE-RUN this cell.

assert( len(df_grouped_subject) == 161 ), "Are you sure you grouped by subjects?"
assert( df_grouped_subject[ df_grouped_subject["Subject"] == "CS" ]["A"].sum() == 38472 ), "Are you sure you counted the right number of each subject?"

# %% [markdown]
# ### Puzzle 3.2: Overall Average GPA
#
# In `df_grouped_subject`, add a new column called `"Overall Average GPA"` that computes the total overall GPA of each subject at Illinois.

# %%
df_grouped_subject["Overall Average GPA"] = df_grouped_subject["Total GPA"] / df_grouped_subject["Total Students"]

# %%
## == TEST CASES for Puzzle 3.2 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error or output, you PASSED all test cases!
# - If this cell results in any errors, check you previous cell, make changes, RE-RUN your code, and then RE-RUN this cell.

assert( abs(df_grouped_subject[ df_grouped_subject["Subject"] == "CS" ]["Overall Average GPA"].sum() - 3.249) < 0.01 ), "Your overall average GPA does not appear correct."

# %% [markdown]
# ### Puzzle 3.3: Find the 15 easiest subjects at Illinois
#
# Finally, find the 15 easiest subjects at Illinois based on their "Overall Average GPA"

# %%
df_easiest_subjects = df_grouped_subject.nlargest(15, "Overall Average GPA")
df_easiest_subjects
# Out:
#     Subject    Year  Number    A+     A    A-   B+    B   B-  C+  ...  C-  D+  \
# 34       CB    4022    1250     0   140     0    0   17    0   0  ...   0   0
# 155     UKR    8048     452     5   190    43   20    8    4   0  ...   0   0
# 40      CHP   14121    1393    42   101    27    8    6    1   0  ...   0   0
# 128    REES    6047     603    32    34     7    2    5    2   0  ...   0   0
# 53     EDUC  120997   10385   326  1788   248  112  102   25  17  ...   6   2
# 33      BUS  499517   27621   519  4566   944  422  232   84  31  ...   9   4
# 137     SBC   24218    6061   162   150    57   23   11    9   2  ...   0   2
# 89       IS  886272  228886  1556  6926  2062  815  566  166  43  ...  15   3
# 126     PSM   16126    4013   121    37    13    4   10    4   2  ...   2   0
# 11      AHS   54360    7096   142   708    37   21   52    4   0  ...   2   0
# 59      EOL   90652   24136    88   960   213  106   86   10   3  ...   0   0
# 41       CI  976726  211275  1429  7884  2083  944  657  175  79  ...  30   7
# 151      TE   98841   18695   474   767   197  105   70   14  11  ...  10   0
# 60     EPOL    8072    2235     1   111    21    3    5    1   0  ...   1   0
# 95      KOR   30208    3043   130   104    42   23   21    6   4  ...   1   0
#
#       D  D-   F   W  Total Students  Total GPA  Average GPA  \
# 34    0   0   0   2             158     613.00     7.767925
# 155   0   0   0   0             271    1041.09    15.181337
# 40    0   0   1   0             189     724.40    26.825308
# 128   1   0   0   0              83     317.69    11.434037
# 53   11   2   9   4            2677   10234.50   226.335488
# 33    9   2  23  10            6880   26302.94   947.761219
# 137   2   0   0   1             421    1606.13    45.727789
# 89   19   1  34  15           12258   46603.61  1671.818854
# 126   0   0   1   0             197     747.71    30.340307
# 11   10   0  15   0            1005    3813.74   102.790092
# 59    4   0   8   3            1487    5640.38   170.202772
# 41   13   1  35  19           13423   50907.53  1835.974090
# 151   1   1  11   6            1683    6372.02   184.681418
# 60    0   0   3   0             147     556.40    15.231700
# 95    0   0   1   1             333    1258.74    56.670767
#
#      Overall Average GPA
# 34              3.879747
# 155             3.841661
# 40              3.832804
# 128             3.827590
# 53              3.823123
# 33              3.823102
# 137             3.815036
# 89              3.801893
# 126             3.795482
# 11              3.794766
# 59              3.793127
# 41              3.792560
# 151             3.786108
# 60              3.785034
# 95              3.780000
#
# [15 rows x 21 columns]

# %% [markdown]
# ### Puzzle 3.4: Find the hardest 15 subjects at Illinois
#
# Find the hardest 15 subjects at Illinois based on their "Overall Average GPA"

# %%
df_hardest_subjects = df_grouped_subject.nsmallest(15, "Overall Average GPA")
df_hardest_subjects
# Out:
#     Subject     Year  Number     A+      A     A-     B+      B     B-     C+  \
# 159      VM   169227   51001      0   1619      8      0   5283      1      0
# 150     TAM   547827   87142   1746   4130   3179   3167   3883   2576   2063
# 105    MATH  4128814  636095  10256  26173  16820  17217  23525  13939  11953
# 121    PHYS  1490544  213894  12103  14472  10042   9617  10233   9037   7444
# 99      LAT    12076     613     14     20     17     16     21      7     14
# 136    SAME     6039     437      2     29     30     20     31     12     14
# 36     CHBE   453296   94175    577   3158   1593   1654   3024   1463   1188
# 38     CHIN     4023     445      0      8      9      4      9      3      1
# 37     CHEM  3225093  294538  10617  40403  16307  16495  21845  12771  11475
# 107     MCB  3413939  434550   6114  12503   9746   9556  11556   7187   5405
# 51      ECE  3104095  533377   7003  20082  11291  10202  13218   7274   5024
# 125      PS  1139802  152743   1915   6951   5350   4438   5768   2974   1891
# 73     GEOL   503311   43651   1530   2280   2246   2052   1816   1438    855
# 52     ECON  5845949  705256  12872  25440  14346  13682  18161   8231   6081
# 127    PSYC  2924649  335172   6692  24195   8859   9015  18369   5710   4185
#
#      ...    C-    D+     D    D-     F     W  Total Students  Total GPA  \
# 159  ...     0     0   283     0     8     8           10288   28812.03
# 150  ...  1353   819  1023   468  1115   151           27665   78022.09
# 105  ...  7394  4253  5342  2215  6863  1383          160344  454039.15
# 121  ...  5409  3536  2638  3035  1704   662           96582  280382.42
# 99   ...     3     1     3     2     8     0             132     388.66
# 136  ...     5     2     2     3     5     1             172     507.38
# 36   ...   666   149   310    59   246    69           16040   47606.30
# 38   ...     1     1     1     1     1     0              42     126.36
# 37   ...  7408  3571  3916  2011  3566  1048          164178  495195.52
# 107  ...  2954  1675  1344   768  1169   348           75097  227767.73
# 51   ...  3297  1145  2156   728  2091   405           90002  277186.73
# 125  ...   926   398   556   214  1079   187           34530  106442.79
# 73   ...   448   278   204   137   407    58           14390   44407.28
# 52   ...  3278  2104  2739  1179  3209   687          119226  369696.89
# 127  ...  1893  1120  2252   503  2118   472           93399  290400.15
#
#      Average GPA  Overall Average GPA
# 159   238.209547             2.800547
# 150   807.339182             2.820245
# 105  6055.159940             2.831657
# 121  2259.908840             2.903050
# 99     17.649451             2.944394
# 136     8.849293             2.949884
# 36    693.003468             2.967974
# 38      6.017143             3.008571
# 37   5224.916815             3.016211
# 107  5235.650819             3.032980
# 51   4893.158668             3.079784
# 125  1785.435633             3.082618
# 73    780.770024             3.085982
# 52   8885.872556             3.100808
# 127  4566.542324             3.109243
#
# [15 rows x 21 columns]

# %% [markdown]
# ### Puzzle 3.5: Find your major!
#
# Finally, find your major/subject in the DataSet and check out how hard it is!
#
# Feel free to look around and explore! Write your code below and write comments to explain what your code does. For example, what are the hardest classes in your major that have had at least 50 students?

# %%
# stats is stats classes with at least 50 students
stats = df[(df["Subject"] == "STAT") & (df["Total Students"] >= 50)]
stats.nsmallest(5, "Average GPA")
# Out:
#        Year    Term YearTerm Subject  Number                   Course Title  \
# 12201  2017  Spring  2017-sp    STAT     410  Statistics and Probability II
# 9913   2017    Fall  2017-fa    STAT     410  Statistics and Probability II
# 46215  2010    Fall  2010-fa    STAT     400   Statistics and Probability I
# 35133  2012    Fall  2012-fa    STAT     400   Statistics and Probability I
# 2083   2019  Spring  2019-sp    STAT     408         Actuarial Statistics I
#
#        A+   A  A-  B+  ...  C-  D+   D  D-   F  W   Primary Instructor  \
# 12201   5  14   3   6  ...  11   0   6   2   6  3   Stepanov, Alexey G
# 9913    4  20   3   1  ...   4   4  13   0   4  1   Stepanov, Alexey G
# 46215   6  11   6   8  ...   5   6   5   1   4  1       Monrad, Ditlev
# 35133  31  22  11  12  ...   4   8   5   6  20  2  Culpepper, Steven A
# 2083    2  11   9   9  ...   3   1   2   8   4  0          Lee, Hyoeun
#
#        Total Students  Total GPA  Average GPA
# 12201              78     196.39     2.517821
# 9913               71     183.69     2.587183
# 46215              98     256.32     2.615510
# 35133             170     445.00     2.617647
# 2083               68     178.41     2.623676
#
# [5 rows x 24 columns]

# %% [markdown]
# # Finale!
#
# You're almost done -- congratulations!
#
# You need to do two more things:
#
# 1. Save your work.  To do this, create a **notebook checkpoint** by using the menu within the notebook to go **File -> Save and Checkpoint**
#
# 2. After you have saved and checkpointed, exit this notebook, and return to the Data Science DISCOVERY page on how to use git to turn this notebook into the course!
