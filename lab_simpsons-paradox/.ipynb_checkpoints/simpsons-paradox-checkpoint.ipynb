# %% [markdown]
# # lab_simpsons-paradox
#
# Hi Data Scientists,
#
# Welcome to the third lab!  In this lab, you will explore using pandas to explore real-world datasets and find if Simpson's Paradox appears in several different datasets.
#
#
# ### Labs are Collaborative
#
# In your lab section (right now!), find a person or two around you and form a group.  Work on this together, making sure all of you understand each component of the lab.
#
#
# ### Getting Help
#
# Remember, there are a lot of ways to get help if you find yourself stuck:
#
# 1. In lab section, your TA, CAs, and your peers are here for you!
#
#
# 2. On the course Piazza page: https://piazza.com/illinois/spring2020/stat107
#
#
# 3. Office Hours:
#
#   - Open office hours **every Monday, Tuesday, Wednesday, and Friday** from 4:00 pm - 6:00 pm in 23 Illini Hall
#
#   - Prof. Wade + Prof. Karle are available every Wednesday from 8:30 am - 10:00 am in 2215 Siebel Center

# %% [markdown]
# # Puzzle 0: Your Group!
#
# Edit the next Python cell to add information about who you're working within your lab section:

# %%
# First, meet your CAs and TA if you haven't already!
# ...first name is enough, we'll know who they are! :)
ta_name = "Anku"
ca1_name = "Jasmine"
ca2_name = "Dean"


# Also, make sure to meet your team for this lab! Find out their name, what major they're in,
# and learn something new about them that you never knew before!
partner1_name = "Brandon"
partner1_netid = "bf5"
partner1_major = "Physics"

partner2_name = "Reilly"
partner2_netid = "rdevine2"
partner2_major = "Systems Engineering"

partner3_name = "David"
partner3_netid = "dalegr2"
partner3_major = "Stats"

# %% [markdown]
# # Puzzle 1: Homecoming Date Night
#
# Imagine you and your partner are trying to find the perfect restaurant for a homecoming date night dinner!  Knowing this process can lead to hours of arguments, you seek out the answer to all of life’s questions: *online reviews*.
#
# The dataset `Black Dog Reviews.csv` (already provided for you as part of the lab code you checked out from git) contains data showing all of the males and females that have reviewed Black Dog in the past year and whether or not they recommended it.  The dataset `Papa Dels Reviews.csv` contains the same information for Papa Dels.
#
#
# ## 1.1: Data Cleaning
#
# Unfortunately, this data was not as tidy as all of our data has been so far. :(
#
# - Open `Black Dog Reviews.csv` and `Papa Dels Reviews.csv` CSV file using any program that can edit spreadsheets.  This can be Microsoft Excel (if you have it installed) or you can upload it to Google Drive and edit it with Google Sheets.
# - Modify the file to ensure all rows that in the `Gender` column has the same value for the two gender categories (as `Male` and `Female`) found in this dataset.
# - Finally, make sure to save the file as a CSV so you can used your cleaned dataset for this lab.
#
#
# ## 1.2. Loading Your DataSet
#
# Load the DataSets you just cleaned into Python:

# %%
# Import the pandas library as pd
import pandas as pd

# %%
df_black = pd.read_csv("Black Dog Reviews.csv")
df_black
# Out:
#     Gender Recommend Black Dog
# 0     Male                 Yes
# 1     Male                 Yes
# 2     Male                 Yes
# 3     Male                 Yes
# 4     Male                 Yes
# 5     Male                  No
# 6     Male                  No
# 7     Male                  No
# 8     Male                  No
# 9     Male                  No
# 10    Male                  No
# 11    Male                  No
# 12    Male                  No
# 13    Male                  No
# 14    Male                  No
# 15  Female                 Yes
# 16  Female                 Yes
# 17  Female                 Yes
# 18  Female                 Yes
# 19  Female                 Yes
# 20  Female                 Yes
# 21  Female                 Yes
# 22  Female                 Yes
# 23  Female                 Yes
# 24  Female                 Yes
# 25  Female                 Yes
# 26  Female                 Yes
# 27  Female                 Yes
# 28  Female                 Yes
# 29  Female                 Yes
# 30  Female                 Yes
# 31  Female                 Yes
# 32  Female                 Yes
# 33  Female                 Yes
# 34  Female                 Yes
# 35  Female                  No
# 36  Female                  No
# 37  Female                  No
# 38  Female                  No
# 39  Female                  No

# %%
## == TEST CASES for Puzzle 1.2 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.

assert(len(df_black_dog) == 40), "The dataframe does not appear to have correct dataset loaded"
## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %%
df_papa = pd.read_csv("Papa Dels Reviews.csv")
df_papa
# Out:
#     Gender Recommend Papa Dels
# 0     Male                 Yes
# 1     Male                 Yes
# 2     Male                 Yes
# 3     Male                 Yes
# 4     Male                 Yes
# 5     Male                 Yes
# 6     Male                 Yes
# 7     Male                 Yes
# 8     Male                 Yes
# 9     Male                 Yes
# 10    Male                 Yes
# 11    Male                 Yes
# 12    Male                 Yes
# 13    Male                 Yes
# 14    Male                 Yes
# 15    Male                 Yes
# 16    Male                 Yes
# 17    Male                 Yes
# 18    Male                  No
# 19    Male                  No
# 20    Male                  No
# 21    Male                  No
# 22    Male                  No
# 23    Male                  No
# 24    Male                  No
# 25    Male                  No
# 26    Male                  No
# 27    Male                  No
# 28    Male                  No
# 29    Male                  No
# 30    Male                  No
# 31    Male                  No
# 32    Male                  No
# 33    Male                  No
# 34    Male                  No
# 35    Male                  No
# 36  Female                 Yes
# 37  Female                 Yes
# 38  Female                 Yes
# 39  Female                 Yes
# 40  Female                 Yes
# 41  Female                 Yes
# 42  Female                 Yes
# 43  Female                 Yes
# 44  Female                 Yes
# 45  Female                  No

# %%
## == TEST CASES for Puzzle 1.2 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.

assert(len(df_papa_del) == 46), "The dataframe does not appear to have correct dataset loaded"
## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## 1.3. Analysis
#
# We want to use the Black Dog dataset to calculate the percentage of women who recommended Black Dog.  Then calculate the percentage of men who recommended Black Dog:

# %%
countmale = df_black[df_black['Gender'] == 'Male']
countfemale = df_black[df_black['Gender'] == 'Female']
length = len(df_black)
male = 15
female = 25

black_dog_female_percent = (len(countfemale[countfemale['Recommend Black Dog'] == 'Yes']) / (female)) * 100
black_dog_female_percent
# Out:
# 80.0

# %%
## == TEST CASES for Puzzle 1.3 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.

assert(black_dog_female_percent == 80), "The percentage of Female who recommended Black Dog does not appear to have been correctly calculated"

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %%
black_dog_male_percent = (len(countmale[countmale['Recommend Black Dog'] == 'Yes']) / (male)) * 100
black_dog_male_percent
# Out:
# 33.33333333333333

# %%
## == TEST CASES for Puzzle 1.3 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.

assert(black_dog_male_percent == 100*(1/3)), "The percentage of Male who recommended Black Dog does not appear to have been correctly calculated"
## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# Similarly, use the Papa Dels dataset to calculate the percentage of women who recommended Papa Dels.  Then calculate the percentage of men who recommended Papa Dels:

# %%
papam = df_papa[df_papa["Gender"] == "Male"]
papaf = df_papa[df_papa["Gender"] == "Female"]
papamale = len(papam)
papafemale = len(papaf)
papa_dels_female_percent = (len(papaf[papaf["Recommend Papa Dels"] == "Yes"]) / papafemale) * 100
papa_dels_female_percent
# Out:
# 90.0

# %%
## == TEST CASES for Puzzle 1.3 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.

assert(papa_dels_female_percent == 90), "The percentage of Female who recommended Papa Dels does not appear to have correctly calculated"
## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %%
papa_dels_male_percent = (len(papam[papam["Recommend Papa Dels"] == "Yes"]) / papamale) * 100
papa_dels_male_percent
# Out:
# 50.0

# %%
## == TEST CASES for Puzzle 1.3 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.

assert(papa_dels_male_percent == 50), "The percentage of Male who recommended Papa Dels does not appear to have been correctly calculated"
## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ### Observe the Results
#
# Run the following cell to format all of your answers as a DataFrame:

# %%
pd.DataFrame( [
    {'Female': black_dog_female_percent, 'Male': black_dog_male_percent },
    {'Female': papa_dels_female_percent, 'Male': papa_dels_male_percent },    
], index=['Black Dog', 'Papa Dels'])
# Out:
#            Female       Male
# Black Dog    80.0  33.333333
# Papa Dels    90.0  50.000000

# %% [markdown]
# ❓ **Question** ❓: Should your homecoming date night be at Black Dog or Papa Dels?
#
# - Does "Black Dog" (Row #1) have higher values or "Papa Dels" (Row #2) have higher values?

# %% [markdown]
# Papa Dels

# %% [markdown]
# ## 1.4. Analysis - Part 2
#
# For our final analysis, let's examine the **overall** percentage of people who recommend each restaurant:

# %%
black_dog_recommended_percent = (len(df_black[df_black["Recommend Black Dog"] == "Yes"]) / len(df_black)) * 100
black_dog_recommended_percent
# Out:
# 62.5

# %%
## == TEST CASES for Puzzle 1.4 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.

assert(black_dog_recommended_percent == 62.5), "The percentage of Overall who recommended Black Dog does not appear to have been correctly calculated"
## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %%
papa_dels_recommended_percent = (len(df_papa[df_papa["Recommend Papa Dels"] == "Yes"]) / len(df_papa)) * 100
papa_dels_recommended_percent
# Out:
# 58.69565217391305

# %%
## == TEST CASES for Puzzle 1.4 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.

assert(papa_dels_recommended_percent == 100*(27/46)), "The percentage of Overall who recommended Papa Dels does not appear to have been correctly calculated"
## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ### Observe the Results
#
# Run the following cell to format all of your answers as a DataFrame:

# %%
pd.DataFrame( [
    {'Female': black_dog_female_percent, 'Male': black_dog_male_percent, 'Overall': black_dog_recommended_percent },
    {'Female': papa_dels_female_percent, 'Male': papa_dels_male_percent, 'Overall': papa_dels_recommended_percent },
], index=['Black Dog', 'Papa Dels'] )
# Out:
#            Female       Male    Overall
# Black Dog    80.0  33.333333  62.500000
# Papa Dels    90.0  50.000000  58.695652

# %% [markdown]
# ❓ **Question** ❓: Should your homecoming date night be at Black Dog or Papa Dels?
#
# - Does "Black Dog" (Row #1) have higher values or "Papa Dels" (Row #2) have higher values for **Overall**?

# %% [markdown]
# Black Dog

# %% [markdown]
# # Puzzle 2: Shoe Size vs Shoes Owned

# %% [markdown]
# From the "Hello" dataset we created on the first day of class, we picked two random questions for us to explore:
#
# - What is your shoe size?
# - How many pairs of shoes do you have?

# %% [markdown]
# ## 2.1: Load the Dataset
#
# - You can find the "Hello" dataset here (make sure to log in with your @illinois.edu address to access it): https://docs.google.com/spreadsheets/d/1uS6OoVsaCNEDwi-ozOXJe7Vn08M-41k7W1cdAlwLIiY/edit#gid=0

# %%
# Read the hello dataset into a DataFrame
df_hello = pd.read_csv("hello.csv")
df_hello
# Out:
#        Name                Major School Year    Phone  \
# 0      Wade     Computer Science       Other  Android
# 1     Karle           Statistics       Other   iPhone
# 2     Grace           Statistics   Sophomore   iPhone
# 3   Miranda          Cs and math   Sophomore   iPhone
# 4      Chen  Information Science    Freshman   iPhone
# ..      ...                  ...         ...      ...
# 86     Suin  Information Science   Sophomore   iPhone
# 87     Nick           Statistics   Sophomore   iPhone
# 88     Howe           Statistics   Sophomore   iPhone
# 89    Davin            Economics      Senior   iPhone
# 90    Tanvi           Statistics   Sophomore   iPhone
#
#                    Computer  Holes in a Straw  Has Dogs  Has Cats  Has Fish  \
# 0    Windows-based computer               2.0         0         1         0
# 1   Mac OS X-based computer               1.0         0         0         0
# 2   Mac OS X-based computer               2.0         1         1         1
# 3   Mac OS X-based computer               1.0         0         1         0
# 4   Mac OS X-based computer               1.0         0         0         0
# ..                      ...               ...       ...       ...       ...
# 86  Mac OS X-based computer               1.0         1         0         0
# 87  Mac OS X-based computer               1.0         1         0         0
# 88   Windows-based computer               1.0         0         1         0
# 89  Mac OS X-based computer               1.0         0         0         0
# 90   Windows-based computer               1.0         0         0         0
#
#     Has Chickens  ...  Programmed before?  \
# 0              0  ...                 Yes
# 1              0  ...                 Yes
# 2              0  ...                  No
# 3              0  ...                 Yes
# 4              0  ...                 Yes
# ..           ...  ...                 ...
# 86             0  ...                  No
# 87             0  ...                 Yes
# 88             0  ...                  No
# 89             0  ...                 Yes
# 90             0  ...                 Yes
#
#                                     Python Background  Statistics Courses  \
# 0   Significant -- I am a wizard when it comes to ...                   2
# 1   Some Python -- I have had one class or written...                  20
# 2   No programming background -- is Python Taylor ...                   3
# 3   No Python, but I've done some programming in o...                   1
# 4   No Python, but I've done some programming in o...                   1
# ..                                                ...                 ...
# 86  No Python, but I've done some programming in o...                   1
# 87  No Python, but I've done some programming in o...                   3
# 88  No programming background -- is Python Taylor ...                   2
# 89  Some Python -- I have had one class or written...                   4
# 90  Some Python -- I have had one class or written...                   3
#
#     Hours Studying Siblings Hours of Sleep  Shoes Owned  \
# 0              3.0        2            8.0            4
# 1              1.0        2            7.0           20
# 2              4.0        1            8.0           40
# 3              4.0        1            6.0           15
# 4              4.0        0            8.0           20
# ..             ...      ...            ...          ...
# 86             5.0        1            8.5           10
# 87             3.0        1            9.0            3
# 88             4.0        1            7.0            5
# 89             3.0        3            5.0           12
# 90             4.0        1            7.0            5
#
#     People Texted Yesterday  Personality  Pineapple on Pizza
# 0                         2    Introvert                 Yes
# 1                        24    Extrovert                 Yes
# 2                         4    Introvert                 Yes
# 3                        20    Introvert                 Yes
# 4                        20    Extrovert                 Yes
# ..                      ...          ...                 ...
# 86                        7    Extrovert                  No
# 87                        4    Introvert                  No
# 88                       20    Introvert                 Yes
# 89                       30    Extrovert                  No
# 90                        9    Introvert                  No
#
# [91 rows x 33 columns]

# %%
## == TEST CASES for Puzzle 2.1 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check you previous cell, make changes, and RE-RUN your code and then this cell.

assert(len(df_hello) == 91), "The dataframe does not appear to have correct dataset loaded"

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## 2.2: Observation Subsets
#
# In this situation, let's define shoes that are strictly greater than size 9 to be "large" and shoes that less than or equal to size 9 are defined to be "small".
#
# Create two DataFrames that contain subsets of our data: one DataFrame that includes everyone who has a "large" shoe size and one DataFrame that includes everyone who has a "small" shoe size:

# %%
df_large_size = df_hello[df_hello["Shoe Size"] > 9]
df_large_size
# Out:
#               Name                                              Major  \
# 0             Wade                                   Computer Science
# 6          Prudhvi                                  Actuarial Science
# 7              Ben            Econometrics and Quantitative Economics
# 9            Grant                    Computer Science and Statistics
# 10         Maureen                            ACE- Financial Planning
# 14           Mason                                         Philosophy
# 18           Jason                                   Computer Science
# 20       Aniruddha                                   Computer Science
# 23         Brandon                                               Math
# 24            Troy                                          Math + CS
# 28          Justin                                         Statistics
# 29          Isaiah                                          Economics
# 31           Ralph               Econometrics, Informational Sciences
# 32  Emily Crawford        Econometrics and maybe Information Science?
# 33         Charles                      Political Science and History
# 34            Nima                                Information Science
# 36            Drew                               Atmospheric Sciences
# 38          Nathan                               Information Sciences
# 39            Alex                                          Economics
# 40             Tim                              Aerospace Engineering
# 43     Christopher                                                Law
# 44            John                                               Math
# 45             Vuk                                         Accounting
# 49         Gustavo                               Information Sciences
# 50            Jack                                         Statistics
# 52          Xavier                              Environmental Science
# 55        Bakhtiar                                          Economics
# 56             Ben                                             any CS
# 57            Josh  I am not sure yet, but I was thinking about In...
# 58          Jeremy                        Information Science (BS/IS)
# 59             Ben                                          Math + CS
# 61         Charlie                                            Biology
# 62           Vivek                                          Economics
# 63          Reilly                     Systems Engineering and Design
# 64          Thomas                               information Sciences
# 65            Neil                             Information Technology
# 67          Yousef            Econometrics and Quantitative Economics
# 69         Cameron                                    Film Production
# 71          Claude                                       Communicaton
# 73           Shawn                      Computer Science + Statistics
# 75          Ishaan                                   Computer Science
# 77         Gabriel                                                NaN
# 78          Takaki                                                 CS
# 80        Citlalli                          Organizational Psychology
# 81       Chiagozie                                Information Science
# 84       Liang Qiu                                Information Science
# 87            Nick                                         Statistics
#
#    School Year    Phone                 Computer  Holes in a Straw  Has Dogs  \
# 0        Other  Android   Windows-based computer               2.0         0
# 6       Junior   iPhone                    Other               2.0         0
# 7    Sophomore  Android   Windows-based computer               2.0         1
# 9    Sophomore   iPhone   Windows-based computer               1.0         0
# 10      Junior   iPhone  Mac OS X-based computer               1.0         0
# 14   Sophomore  Android   Windows-based computer               2.0         0
# 18      Junior   iPhone  Mac OS X-based computer               1.0         0
# 20   Sophomore   iPhone  Mac OS X-based computer               1.0         0
# 23   Sophomore   iPhone   Windows-based computer               1.0         0
# 24    Freshman   iPhone  Mac OS X-based computer               2.0         0
# 28      Junior  Android   Windows-based computer               2.0         1
# 29      Senior   iPhone   Windows-based computer               1.0         1
# 31   Sophomore   iPhone  Mac OS X-based computer               1.0         0
# 32    Freshman   iPhone  Mac OS X-based computer               1.0         0
# 33      Senior   iPhone   Windows-based computer               1.0         1
# 34   Sophomore   iPhone   Windows-based computer               2.0         0
# 36      Junior   iPhone   Windows-based computer               1.0         1
# 38    Freshman   iPhone  Mac OS X-based computer               1.0         0
# 39      Junior   iPhone   Windows-based computer               1.0         1
# 40    Freshman   iPhone   Windows-based computer               2.0         1
# 43       Other   iPhone   Windows-based computer               2.0         0
# 44   Sophomore  Android   Windows-based computer               0.0         0
# 45      Senior  Android   Windows-based computer               1.0         0
# 49   Sophomore  Android   Windows-based computer               1.0         1
# 50    Freshman   iPhone   Windows-based computer               1.0         1
# 52      Junior   iPhone  Mac OS X-based computer               1.0         1
# 55      Senior   iPhone  Mac OS X-based computer               1.0         0
# 56   Sophomore  Android     Linux-based computer              20.0         0
# 57    Freshman  Android   Windows-based computer               1.0         1
# 58   Sophomore   iPhone  Mac OS X-based computer               1.0         0
# 59    Freshman   iPhone   Windows-based computer               1.0         0
# 61   Sophomore  Android   Windows-based computer               1.0         0
# 62      Senior   iPhone  Mac OS X-based computer               2.0         1
# 63      Senior   iPhone   Windows-based computer               1.0         1
# 64   Sophomore   iPhone   Windows-based computer               0.0         1
# 65      Junior   iPhone  Mac OS X-based computer               1.0         1
# 67    Freshman   iPhone  Mac OS X-based computer               1.0         0
# 69      Junior   iPhone  Mac OS X-based computer               1.0         1
# 71      Junior  Android   Windows-based computer               1.0         0
# 73    Freshman   iPhone   Windows-based computer               1.0         1
# 75      Senior   iPhone  Mac OS X-based computer               1.0         1
# 77       Other  Android  Mac OS X-based computer               1.0         0
# 78      Junior  Android   Windows-based computer               1.0         0
# 80      Junior  Android   Windows-based computer               1.0         1
# 81    Freshman   iPhone  Mac OS X-based computer               2.0         0
# 84    Freshman   iPhone   Windows-based computer               2.0         0
# 87   Sophomore   iPhone  Mac OS X-based computer               1.0         1
#
#     Has Cats  Has Fish  Has Chickens  ...  Programmed before?  \
# 0          1         0             0  ...                 Yes
# 6          0         0             0  ...                 Yes
# 7          0         0             0  ...                 Yes
# 9          0         0             0  ...                 Yes
# 10         0         0             0  ...                  No
# 14         0         0             0  ...                 Yes
# 18         0         0             0  ...                  No
# 20         0         0             0  ...                 Yes
# 23         0         0             0  ...                 Yes
# 24         1         0             0  ...                 Yes
# 28         0         0             0  ...                 Yes
# 29         0         0             0  ...                 Yes
# 31         0         0             0  ...                 Yes
# 32         1         0             0  ...                  No
# 33         0         0             0  ...                  No
# 34         0         0             0  ...                 Yes
# 36         0         0             0  ...                 Yes
# 38         1         1             0  ...                  No
# 39         0         0             0  ...                  No
# 40         1         0             0  ...                 Yes
# 43         0         0             1  ...                  No
# 44         1         0             0  ...                 Yes
# 45         0         0             0  ...                 Yes
# 49         0         0             0  ...                 Yes
# 50         0         0             0  ...                  No
# 52         0         0             0  ...                 Yes
# 55         0         0             0  ...                 Yes
# 56         0         0             0  ...                 Yes
# 57         0         0             0  ...                  No
# 58         0         0             0  ...                 Yes
# 59         1         0             0  ...                 Yes
# 61         0         0             0  ...                 Yes
# 62         0         0             0  ...                 Yes
# 63         0         0             0  ...                 Yes
# 64         1         0             0  ...                 Yes
# 65         0         0             0  ...                 Yes
# 67         1         0             0  ...                  No
# 69         0         0             0  ...                 Yes
# 71         0         0             0  ...                  No
# 73         0         0             0  ...                 Yes
# 75         1         0             0  ...                 Yes
# 77         1         0             0  ...                 Yes
# 78         0         0             0  ...                  No
# 80         0         0             0  ...                 Yes
# 81         0         0             0  ...                 Yes
# 84         0         1             0  ...                  No
# 87         0         0             0  ...                 Yes
#
#                                     Python Background  Statistics Courses  \
# 0   Significant -- I am a wizard when it comes to ...                   2
# 6   No Python, but I've done some programming in o...                   3
# 7   Some Python -- I have had one class or written...                   2
# 9   Some Python -- I have had one class or written...                   3
# 10  No programming background -- is Python Taylor ...                   2
# 14  Some Python -- I have had one class or written...                   1
# 18  No programming background -- is Python Taylor ...                   0
# 20  No Python, but I've done some programming in o...                   3
# 23  Some Python -- I have had one class or written...                   0
# 24  Some Python -- I have had one class or written...                   0
# 28  No Python, but I've done some programming in o...                   3
# 29  Some Python -- I have had one class or written...                   3
# 31  Some Python -- I have had one class or written...                   1
# 32  No programming background -- is Python Taylor ...                   1
# 33  No programming background -- is Python Taylor ...                   0
# 34  No Python, but I've done some programming in o...                   0
# 36  Significant -- I am a wizard when it comes to ...                   1
# 38  No programming background -- is Python Taylor ...                   1
# 39  No programming background -- is Python Taylor ...                   3
# 40  Some Python -- I have had one class or written...                   1
# 43  No programming background -- is Python Taylor ...                   2
# 44  Some Python -- I have had one class or written...                   1
# 45  No Python, but I've done some programming in o...                   2
# 49  No Python, but I've done some programming in o...                   2
# 50  No programming background -- is Python Taylor ...                   1
# 52  Some Python -- I have had one class or written...                   1
# 55  Some Python -- I have had one class or written...                   5
# 56  No Python, but I've done some programming in o...                   2
# 57  No programming background -- is Python Taylor ...                   0
# 58  No Python, but I've done some programming in o...                   1
# 59  Some Python -- I have had one class or written...                   2
# 61  No Python, but I've done some programming in o...                   2
# 62  Some Python -- I have had one class or written...                   6
# 63  Some Python -- I have had one class or written...                   1
# 64  Some Python -- I have had one class or written...                   0
# 65  Some Python -- I have had one class or written...                   3
# 67  No programming background -- is Python Taylor ...                   1
# 69  Some Python -- I have had one class or written...                   2
# 71  No programming background -- is Python Taylor ...                   1
# 73  No Python, but I've done some programming in o...                   0
# 75  Some Python -- I have had one class or written...                   1
# 77  No Python, but I've done some programming in o...                   0
# 78                                                NaN                   2
# 80  No Python, but I've done some programming in o...                   2
# 81  Some Python -- I have had one class or written...                   0
# 84  No programming background -- is Python Taylor ...                   1
# 87  No Python, but I've done some programming in o...                   3
#
#     Hours Studying Siblings Hours of Sleep  Shoes Owned  \
# 0              3.0        2            8.0            4
# 6              4.0        1            7.0            3
# 7              4.0        1            8.0            4
# 9              5.0        1            8.0            5
# 10             2.0        2            8.0           12
# 14             8.0        1            7.0            3
# 18             3.0        2            8.0           10
# 20             4.0        0            6.0            6
# 23             5.0        1            7.0            4
# 24             4.0        1            7.0            7
# 28             3.0        1            8.0            9
# 29             2.0        2            7.0           15
# 31             3.0        2            6.0            7
# 32             4.0        1            7.0           11
# 33             2.0        1            8.0            2
# 34             3.0        1            8.0            5
# 36             1.0        2            8.0            3
# 38             2.0        2            7.0           12
# 39             2.0        1            8.0           12
# 40             0.5        2            7.0            3
# 43             5.0        7            7.0            5
# 44             0.5        3            9.0            2
# 45             3.0        2            7.5            4
# 49             3.0        3            5.0           17
# 50             3.0        2            7.0           10
# 52             4.0        2            5.0            8
# 55             2.0        2            8.0            5
# 56             3.0        0            8.0            2
# 57             2.0        1            8.0            7
# 58             3.0        2            8.0           10
# 59             1.5        1            8.0           30
# 61             3.0        2            9.0            3
# 62            12.0        2            8.0            6
# 63             4.0        2            6.5           15
# 64             3.0        1            7.0            4
# 65             2.0        2            7.0           20
# 67             4.0        7            7.0           10
# 69             3.0        2            8.0            5
# 71             2.0        1            6.0            4
# 73             2.0        1            7.0           10
# 75             4.0        1            7.0            9
# 77            20.0        3            8.0           12
# 78             4.0        1            7.0            2
# 80             5.0        1            7.0           10
# 81             3.0        1            8.0            7
# 84             1.0        1            5.0            5
# 87             3.0        1            9.0            3
#
#     People Texted Yesterday  Personality  Pineapple on Pizza
# 0                         2    Introvert                 Yes
# 6                         5    Extrovert                 Yes
# 7                        11    Introvert                  No
# 9                         5    Introvert                  No
# 10                       13    Introvert                 Yes
# 14                       10    Introvert                  No
# 18                       15    Introvert                 Yes
# 20                      180    Introvert                  No
# 23                        2          NaN                  No
# 24                        3    Introvert                 Yes
# 28                        5    Introvert                 Yes
# 29                       24    Introvert                  No
# 31                        4    Extrovert                  No
# 32                       75    Extrovert                 Yes
# 33                        4    Introvert                  No
# 34                        5    Introvert                 Yes
# 36                        4    Introvert                 Yes
# 38                        8    Introvert                 Yes
# 39                        3    Extrovert                  No
# 40                        3    Introvert                 Yes
# 43                        5    Introvert                  No
# 44                        9    Introvert                 Yes
# 45                       28    Introvert                  No
# 49                       11    Introvert                 Yes
# 50                       15    Extrovert                 Yes
# 52                        5    Extrovert                  No
# 55                        8    Introvert                  No
# 56                        0    Introvert                  No
# 57                      100    Extrovert                 Yes
# 58                       15    Extrovert                 Yes
# 59                        7    Extrovert                  No
# 61                        3    Introvert                 Yes
# 62                       25    Extrovert                  No
# 63                       80    Introvert                 Yes
# 64                       18    Introvert                 Yes
# 65                       15    Extrovert                  No
# 67                        2    Introvert                  No
# 69                        6    Extrovert                  No
# 71                        6    Introvert                  No
# 73                        7    Extrovert                  No
# 75                       22    Introvert                 Yes
# 77                       10    Extrovert                  No
# 78                        5    Introvert                  No
# 80                        9    Extrovert                 Yes
# 81                        4    Introvert                  No
# 84                       12    Introvert                  No
# 87                        4    Introvert                  No
#
# [47 rows x 33 columns]

# %%
## == TEST CASES for Puzzle 2.2 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check you previous cell, make changes, and RE-RUN your code and then this cell.

assert(len(df_large_size) == 47), "The dataframe does not appear to have been correct subset"

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %%
df_small_size = df_hello[df_hello["Shoe Size"] <= 9]
df_small_size
# Out:
#               Name                          Major School Year    Phone  \
# 1            Karle                     Statistics       Other   iPhone
# 2            Grace                     Statistics   Sophomore   iPhone
# 3          Miranda                    Cs and math   Sophomore   iPhone
# 4             Chen            Information Science    Freshman   iPhone
# 5           Minjae           Information Sciences    Freshman   iPhone
# 8         Jennifer                         Design      Junior   iPhone
# 11           Bohan                            NaN    Freshman   iPhone
# 12           Grace                            NaN   Sophomore   iPhone
# 13          Daniel                     Statistics    Freshman   iPhone
# 15           chloe              political science   Sophomore   iPhone
# 16         Chulong                      Economics   Sophomore   iPhone
# 17         Mariama              Political Science    Freshman   iPhone
# 19            Rutu              Computer Engineer      Senior   iPhone
# 21           Yosra                      Economics    Freshman   iPhone
# 22           Katie               Creative Writing       Other   iPhone
# 25          Emilie                    Linguistics    Freshman  Android
# 26         Sabrina                 CS + Chemistry   Sophomore  Android
# 27         Brianna                 Global Studies      Junior   iPhone
# 30          Serena                           math      Senior   iPhone
# 35        Michelle  Statistics + Computer Science   Sophomore   iPhone
# 37          LiPing              Political Science      Junior   iPhone
# 41           Raina                Math + Business      Senior   iPhone
# 42             tim                      math + CS    Freshman  Android
# 46            Cara           Chemical Engineering       Other  Android
# 47          Yehjee                     Statistics    Freshman   iPhone
# 48             Eli                 Urban Planning      Senior   iPhone
# 51           Elise                      Economics   Sophomore   iPhone
# 53            Pete                           Econ      Senior   iPhone
# 54            Vada                    Advertising   Sophomore   iPhone
# 60          Aleksi            Integrative Biology    Freshman   iPhone
# 66           Xulin               Computer Science   Sophomore   iPhone
# 68  Jose Hernandez              Political Science   Sophomore   iPhone
# 70         David A            Information Science   Sophomore   iPhone
# 72          yuchen           electric engineering    Freshman   iPhone
# 74   Sabah Hussain         Industrial engineering      Junior   iPhone
# 76          Olivia                     Psychology      Junior  Android
# 79        Isabelle                  Commincations      Junior   iPhone
# 82           Yijia                    Mathematics   Sophomore   iPhone
# 83           Derek                     Psychology   Sophomore  Android
# 85          Feliks                     Statistics      Junior   iPhone
# 86            Suin            Information Science   Sophomore   iPhone
# 88            Howe                     Statistics   Sophomore   iPhone
# 89           Davin                      Economics      Senior   iPhone
# 90           Tanvi                     Statistics   Sophomore   iPhone
#
#                    Computer  Holes in a Straw  Has Dogs  Has Cats  Has Fish  \
# 1   Mac OS X-based computer               1.0         0         0         0
# 2   Mac OS X-based computer               2.0         1         1         1
# 3   Mac OS X-based computer               1.0         0         1         0
# 4   Mac OS X-based computer               1.0         0         0         0
# 5   Mac OS X-based computer               2.0         0         0         1
# 8   Mac OS X-based computer               2.0         0         0         1
# 11   Windows-based computer               1.0         0         0         0
# 12  Mac OS X-based computer               1.0         0         0         0
# 13   Windows-based computer               2.0         0         1         0
# 15   Windows-based computer               2.0         1         0         0
# 16   Windows-based computer               0.0         0         0         0
# 17  Mac OS X-based computer               1.0         0         0         0
# 19  Mac OS X-based computer               1.0         0         0         0
# 21  Mac OS X-based computer               2.0         0         0         0
# 22   Windows-based computer               2.0         0         0         0
# 25   Windows-based computer               2.0         0         1         0
# 26   Windows-based computer               1.0         0         0         0
# 27   Windows-based computer               1.0         0         1         0
# 30  Mac OS X-based computer               1.0         1         1         0
# 35  Mac OS X-based computer               1.0         1         0         0
# 37  Mac OS X-based computer               1.0         0         0         1
# 41   Windows-based computer               1.0         0         0         0
# 42   Windows-based computer               1.0         0         0         0
# 46   Windows-based computer               NaN         1         1         0
# 47  Mac OS X-based computer               2.0         0         0         0
# 48  Mac OS X-based computer               1.0         0         1         0
# 51  Mac OS X-based computer               1.0         0         0         0
# 53  Mac OS X-based computer               1.0         0         0         0
# 54  Mac OS X-based computer               1.0         0         1         0
# 60  Mac OS X-based computer               1.0         1         1         0
# 66  Mac OS X-based computer               2.0         0         0         0
# 68  Mac OS X-based computer               2.0         0         0         0
# 70   Windows-based computer               1.0         1         0         0
# 72   Windows-based computer               1.0         1         0         0
# 74  Mac OS X-based computer               2.0         0         0         0
# 76   Windows-based computer               1.0         0         0         0
# 79  Mac OS X-based computer               1.0         0         0         0
# 82  Mac OS X-based computer               1.0         0         0         0
# 83   Windows-based computer               2.0         1         1         0
# 85   Windows-based computer               1.0         1         0         0
# 86  Mac OS X-based computer               1.0         1         0         0
# 88   Windows-based computer               1.0         0         1         0
# 89  Mac OS X-based computer               1.0         0         0         0
# 90   Windows-based computer               1.0         0         0         0
#
#     Has Chickens  ...  Programmed before?  \
# 1              0  ...                 Yes
# 2              0  ...                  No
# 3              0  ...                 Yes
# 4              0  ...                 Yes
# 5              0  ...                 Yes
# 8              0  ...                  No
# 11             0  ...                 Yes
# 12             0  ...                  No
# 13             0  ...                  No
# 15             0  ...                 Yes
# 16             0  ...                  No
# 17             0  ...                  No
# 19             0  ...                 Yes
# 21             0  ...                 Yes
# 22             0  ...                  No
# 25             0  ...                 Yes
# 26             0  ...                 Yes
# 27             0  ...                 Yes
# 30             0  ...                 Yes
# 35             0  ...                 Yes
# 37             0  ...                  No
# 41             0  ...                 Yes
# 42             0  ...                 Yes
# 46             0  ...                 Yes
# 47             0  ...                  No
# 48             0  ...                 Yes
# 51             0  ...                 Yes
# 53             0  ...                  No
# 54             0  ...                  No
# 60             0  ...                 Yes
# 66             0  ...                 Yes
# 68             0  ...                  No
# 70             0  ...                 Yes
# 72             0  ...                 Yes
# 74             0  ...                 Yes
# 76             0  ...                  No
# 79             0  ...                  No
# 82             0  ...                 Yes
# 83             0  ...                  No
# 85             0  ...                 Yes
# 86             0  ...                  No
# 88             0  ...                  No
# 89             0  ...                 Yes
# 90             0  ...                 Yes
#
#                                     Python Background  Statistics Courses  \
# 1   Some Python -- I have had one class or written...                  20
# 2   No programming background -- is Python Taylor ...                   3
# 3   No Python, but I've done some programming in o...                   1
# 4   No Python, but I've done some programming in o...                   1
# 5   No Python, but I've done some programming in o...                   1
# 8   No programming background -- is Python Taylor ...                   2
# 11  Some Python -- I have had one class or written...                   1
# 12  No programming background -- is Python Taylor ...                   1
# 13  No programming background -- is Python Taylor ...                   0
# 15  Some Python -- I have had one class or written...                   1
# 16  No programming background -- is Python Taylor ...                   1
# 17  No programming background -- is Python Taylor ...                   1
# 19  Significant -- I am a wizard when it comes to ...                   0
# 21  No Python, but I've done some programming in o...                   0
# 22  No programming background -- is Python Taylor ...                   0
# 25  No Python, but I've done some programming in o...                   0
# 26  No Python, but I've done some programming in o...                   1
# 27  Some Python -- I have had one class or written...                   1
# 30  Some Python -- I have had one class or written...                   4
# 35  Some Python -- I have had one class or written...                   3
# 37  No programming background -- is Python Taylor ...                   1
# 41  No Python, but I've done some programming in o...                   1
# 42  No Python, but I've done some programming in o...                   1
# 46  Some Python -- I have had one class or written...                   2
# 47  No programming background -- is Python Taylor ...                   2
# 48  Some Python -- I have had one class or written...                   6
# 51  Some Python -- I have had one class or written...                   1
# 53  No programming background -- is Python Taylor ...                   2
# 54  No programming background -- is Python Taylor ...                   1
# 60  No Python, but I've done some programming in o...                   1
# 66  No Python, but I've done some programming in o...                   2
# 68  No programming background -- is Python Taylor ...                   1
# 70  No Python, but I've done some programming in o...                   4
# 72  No Python, but I've done some programming in o...                   1
# 74  No programming background -- is Python Taylor ...                   3
# 76  No programming background -- is Python Taylor ...                   2
# 79  No programming background -- is Python Taylor ...                   2
# 82  Some Python -- I have had one class or written...                   1
# 83  No Python, but I've done some programming in o...                   2
# 85  Some Python -- I have had one class or written...                   2
# 86  No Python, but I've done some programming in o...                   1
# 88  No programming background -- is Python Taylor ...                   2
# 89  Some Python -- I have had one class or written...                   4
# 90  Some Python -- I have had one class or written...                   3
#
#     Hours Studying Siblings Hours of Sleep  Shoes Owned  \
# 1              1.0        2            7.0           20
# 2              4.0        1            8.0           40
# 3              4.0        1            6.0           15
# 4              4.0        0            8.0           20
# 5              5.0        1            7.0            3
# 8              3.0        2            6.0           20
# 11             7.0        0            7.0            5
# 12             4.0        1            7.0            8
# 13             1.0        1            9.0            3
# 15             5.0        1            8.5           25
# 16             3.0        0            7.0            4
# 17             2.5        3            7.5           12
# 19             3.0        2            7.0           15
# 21             2.0        2            5.0            9
# 22             5.0        1            8.0            6
# 25             7.0        1            7.5           13
# 26             6.0        1            7.0           16
# 27             2.0        4            7.0           15
# 30             3.0        0            7.0           13
# 35             5.0        1            7.0           19
# 37             3.0        2            8.0           10
# 41             2.0        2            6.5            7
# 42             2.0        0            8.0            2
# 46             4.0        1            8.0           10
# 47             3.0        1            7.0            6
# 48             4.0        2            5.0            8
# 51             3.0        4            8.0           12
# 53             3.0        2            7.0            4
# 54             2.0        2            8.0           15
# 60             6.0        1            7.5           25
# 66             5.0        0            7.0            6
# 68             1.0        3            7.5           12
# 70             0.0        4            8.0           20
# 72             3.0        1            7.0            3
# 74             3.0        2            7.0            8
# 76             3.0        1            7.0           20
# 79             1.0        2            8.0            7
# 82             4.0        1            7.0            8
# 83             2.0        6            1.0            3
# 85             3.5        3            8.3            4
# 86             5.0        1            8.5           10
# 88             4.0        1            7.0            5
# 89             3.0        3            5.0           12
# 90             4.0        1            7.0            5
#
#     People Texted Yesterday  Personality  Pineapple on Pizza
# 1                        24    Extrovert                 Yes
# 2                         4    Introvert                 Yes
# 3                        20    Introvert                 Yes
# 4                        20    Extrovert                 Yes
# 5                        21    Introvert                 Yes
# 8                         7    Introvert                 Yes
# 11                        5    Introvert                 Yes
# 12                        5    Introvert                  No
# 13                        5    Extrovert                  No
# 15                       20    Introvert                  No
# 16                        3    Introvert                 Yes
# 17                       50    Extrovert                  No
# 19                       10    Extrovert                 Yes
# 21                        9    Extrovert                  No
# 22                       15    Introvert                  No
# 25                       10    Introvert                 Yes
# 26                       13    Introvert                 Yes
# 27                       20    Extrovert                 Yes
# 30                       10    Introvert                  No
# 35                       11    Introvert                  No
# 37                       12    Introvert                 Yes
# 41                       33    Introvert                  No
# 42                        3    Extrovert                 Yes
# 46                        7    Introvert                  No
# 47                       11    Introvert                 Yes
# 48                       22    Introvert                 Yes
# 51                       30    Extrovert                  No
# 53                        8    Introvert                 Yes
# 54                       20    Extrovert                 Yes
# 60                       22    Introvert                  No
# 66                       10    Introvert                  No
# 68                        7    Introvert                  No
# 70                        9    Extrovert                 Yes
# 72                        3    Introvert                 Yes
# 74                        3    Introvert                  No
# 76                       11    Introvert                 Yes
# 79                       20    Extrovert                 Yes
# 82                        5    Introvert                 Yes
# 83                       28    Introvert                  No
# 85                        8    Introvert                  No
# 86                        7    Extrovert                  No
# 88                       20    Introvert                 Yes
# 89                       30    Extrovert                  No
# 90                        9    Introvert                  No
#
# [44 rows x 33 columns]

# %%
## == TEST CASES for Puzzle 2.2 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check you previous cell, make changes, and RE-RUN your code and then this cell.

assert(len(df_small_size) == 44), "The dataframe does not appear to have been correct subset"
## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## 2.3: Average Number of Pairs of Shoes
#
# Find the average number of pairs of shoes of each group:

# %%
large_avg_shoes = df_large_size['Shoes Owned'].mean()
large_avg_shoes
# Out:
# 7.702127659574468

# %%
## == TEST CASES for Puzzle 2.3 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check you previous cell, make changes, and RE-RUN your code and then this cell.

assert(large_avg_shoes == 362/47),  "The average number of pairs of shoes in large shoe-size dataframe does not appear to seem correct. Make sure you are taking mean of the correct variable."
## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %%
small_avg_shoes = df_small_size['Shoes Owned'].mean()
small_avg_shoes
# Out:
# 11.431818181818182

# %%
## == TEST CASES for Puzzle 2.3 ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check you previous cell, make changes, and RE-RUN your code and then this cell.

assert(small_avg_shoes == 503 / 44),  "The average number of pairs of shoes in small shoe-size dataframe does not appear to seem correct. Make sure you are taking mean of the correct variable."
## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## 2.4. Observations
#
# Answer the next two questions with 1-2 sentences each.  The cells after the question text are editable -- you should double-click and replace the text with your answer:

# %% [markdown]
# ### Q1: Is there a difference in the number of shoes owned between the two groups?

# %% [markdown]
# Yes. People with smaller shoe sizes seemed to own more pair of shoes.

# %% [markdown]
# ### Q2: What might be some possible confounding variable in this result?

# %% [markdown]
# A possible confounder can be gender and age. Shoe sizes increases with age generally, if you are older, it means you have more access to money and freedom to buy more shoes, while younger people most likely do not have access to money as much as older people.

# %% [markdown]
# # Finale!
#
# You're almost done -- congratulations!
#
# You need to do two more things:
#
# 1. Save your work.  To do this, create a **notebook checkpoint** by using the menu within the notebook to go **File -> Save and Checkpoint**
#
# 2. After you have saved and checkpointed, exit this notebook and return to the Data Science Discovery page on how to use git to turn this notebook into the course!
