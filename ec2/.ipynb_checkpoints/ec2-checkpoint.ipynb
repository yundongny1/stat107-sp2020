# %% [markdown]
# # EC Notebook for Week 2: Blocking and Conditionals
#
# This extra credit Python notebook will let you practice the material you saw in lecture!  Completing all parts of this notebook will earn +1 extra credit point to your grade in STAT 107!
#
# This notebook is worth +1 if turned in before 11:59pm on **Friday, Feb. 7**.

# %% [markdown]
# ## 1. Loading pandas and importing data
#
# For this notebook, we will continue to use the "Hello" dataset introduced last lecture!
#
# Using your @illinois.edu address, download the dataset as a CSV and **make sure to save or move it to the same directory as this notebook**: https://docs.google.com/spreadsheets/d/1uS6OoVsaCNEDwi-ozOXJe7Vn08M-41k7W1cdAlwLIiY/edit?usp=sharing
#
# Use the following cell to load the pandas library and read the DataSet as a DataFrame:

# %%
import pandas as pd
df = pd.read_csv("Hello.csv")
df.sample (n=5)
# Out:
#         Name              Major School Year    Phone                 Computer  \
# 19      Rutu  Computer Engineer      Senior   iPhone  Mac OS X-based computer
# 61     Vivek          Economics      Senior   iPhone  Mac OS X-based computer
# 8   Jennifer             Design      Junior   iPhone  Mac OS X-based computer
# 0       Wade   Computer Science       Other  Android   Windows-based computer
# 16   Chulong          Economics   Sophomore   iPhone   Windows-based computer
#
#     Holes in a Straw  Has Dogs  Has Cats  Has Fish  Has Chickens  ...  \
# 19               1.0         0         0         0             0  ...
# 61               2.0         1         0         0             0  ...
# 8                2.0         0         0         1             0  ...
# 0                2.0         0         1         0             0  ...
# 16               0.0         0         0         0             0  ...
#
#     Programmed before?                                  Python Background  \
# 19                 Yes  Significant -- I am a wizard when it comes to ...
# 61                 Yes  Some Python -- I have had one class or written...
# 8                   No  No programming background -- is Python Taylor ...
# 0                  Yes  Significant -- I am a wizard when it comes to ...
# 16                  No  No programming background -- is Python Taylor ...
#
#     Statistics Courses  Hours Studying Siblings Hours of Sleep  Shoes Owned  \
# 19                   0             3.0        2            7.0           15
# 61                   6            12.0        2            8.0            6
# 8                    2             3.0        2            6.0           20
# 0                    2             3.0        2            8.0            4
# 16                   1             3.0        0            7.0            4
#
#     People Texted Yesterday  Personality  Pineapple on Pizza
# 19                       10    Extrovert                 Yes
# 61                       25    Extrovert                  No
# 8                         7    Introvert                 Yes
# 0                         2    Introvert                 Yes
# 16                        3    Introvert                 Yes
#
# [5 rows x 33 columns]

# %% [markdown]
# ## 2. Creating a Control Group
#
# In lecture, we worked out a puzzle.  From the lecture handout:
#
# > Use Python to create a control group of 20 students, using blocking to control for the influence we suspect having more than 1 siblings might have.  Make sure you have an equal number of students with 0 or 1 sibling and an equal number of students with 2 or more siblings.
#
# We will complete the code in a notebook this in four separate steps to get practice on each part.

# %% [markdown]
# ### 2.1: Sibling Block #1 -- Zero or One Siblings
#
# Creating a DataFrame that contains all students with 0 or 1 siblings and call it `block1`:

# %%
block1 = df[df["Siblings"] <= 1]



# Show a few rows to check if the block has the data we expect:
block1.sample(n=10)
# Out:
#          Name                                    Major School Year    Phone  \
# 7         Ben  Econometrics and Quantitative Economics   Sophomore  Android
# 13     Daniel                               Statistics    Freshman   iPhone
# 3     Miranda                              Cs and math   Sophomore   iPhone
# 89      Tanvi                               Statistics   Sophomore   iPhone
# 83  Liang Qiu                      Information Science    Freshman   iPhone
# 58        Ben                                Math + CS    Freshman   iPhone
# 20  Aniruddha                         Computer Science   Sophomore   iPhone
# 75     Olivia                               Psychology      Junior  Android
# 30     Serena                                     math      Senior   iPhone
# 59     Aleksi                      Integrative Biology    Freshman   iPhone
#
#                    Computer  Holes in a Straw  Has Dogs  Has Cats  Has Fish  \
# 7    Windows-based computer               2.0         1         0         0
# 13   Windows-based computer               2.0         0         1         0
# 3   Mac OS X-based computer               1.0         0         1         0
# 89   Windows-based computer               1.0         0         0         0
# 83   Windows-based computer               2.0         0         0         1
# 58   Windows-based computer               1.0         0         1         0
# 20  Mac OS X-based computer               1.0         0         0         0
# 75   Windows-based computer               1.0         0         0         0
# 30  Mac OS X-based computer               1.0         1         1         0
# 59  Mac OS X-based computer               1.0         1         1         0
#
#     Has Chickens  ...  Programmed before?  \
# 7              0  ...                 Yes
# 13             0  ...                  No
# 3              0  ...                 Yes
# 89             0  ...                 Yes
# 83             0  ...                  No
# 58             0  ...                 Yes
# 20             0  ...                 Yes
# 75             0  ...                  No
# 30             0  ...                 Yes
# 59             0  ...                 Yes
#
#                                     Python Background  Statistics Courses  \
# 7   Some Python -- I have had one class or written...                   2
# 13  No programming background -- is Python Taylor ...                   0
# 3   No Python, but I've done some programming in o...                   1
# 89  Some Python -- I have had one class or written...                   3
# 83  No programming background -- is Python Taylor ...                   1
# 58  Some Python -- I have had one class or written...                   2
# 20  No Python, but I've done some programming in o...                   3
# 75  No programming background -- is Python Taylor ...                   2
# 30  Some Python -- I have had one class or written...                   4
# 59  No Python, but I've done some programming in o...                   1
#
#     Hours Studying Siblings Hours of Sleep  Shoes Owned  \
# 7              4.0        1            8.0            4
# 13             1.0        1            9.0            3
# 3              4.0        1            6.0           15
# 89             4.0        1            7.0            5
# 83             1.0        1            5.0            5
# 58             1.5        1            8.0           30
# 20             4.0        0            6.0            6
# 75             3.0        1            7.0           20
# 30             3.0        0            7.0           13
# 59             6.0        1            7.5           25
#
#     People Texted Yesterday  Personality  Pineapple on Pizza
# 7                        11    Introvert                  No
# 13                        5    Extrovert                  No
# 3                        20    Introvert                 Yes
# 89                        9    Introvert                  No
# 83                       12    Introvert                  No
# 58                        7    Extrovert                  No
# 20                      180    Introvert                  No
# 75                       11    Introvert                 Yes
# 30                       10    Introvert                  No
# 59                       22    Introvert                  No
#
# [10 rows x 33 columns]

# %% [markdown]
# ### 2.2: Sibling Block #2 -- Two or More Siblings
#
# Create a DataFrame that contains all students with 2 or more siblings and call it `block2`:

# %%
block2 = df[df["Siblings"] > 1 ]


# Show a few rows to check if the block has the data we expect:
block2.sample(n=3)
# Out:
#       Name                   Major School Year    Phone  \
# 64    Neil  Information Technology      Junior   iPhone
# 84  Feliks              Statistics      Junior   iPhone
# 44     Vuk              Accounting      Senior  Android
#
#                    Computer  Holes in a Straw  Has Dogs  Has Cats  Has Fish  \
# 64  Mac OS X-based computer               1.0         1         0         0
# 84   Windows-based computer               1.0         1         0         0
# 44   Windows-based computer               1.0         0         0         0
#
#     Has Chickens  ...  Programmed before?  \
# 64             0  ...                 Yes
# 84             0  ...                 Yes
# 44             0  ...                 Yes
#
#                                     Python Background  Statistics Courses  \
# 64  Some Python -- I have had one class or written...                   3
# 84  Some Python -- I have had one class or written...                   2
# 44  No Python, but I've done some programming in o...                   2
#
#     Hours Studying Siblings Hours of Sleep  Shoes Owned  \
# 64             2.0        2            7.0           20
# 84             3.5        3            8.3            4
# 44             3.0        2            7.5            4
#
#     People Texted Yesterday  Personality  Pineapple on Pizza
# 64                       15    Extrovert                  No
# 84                        8    Introvert                  No
# 44                       28    Introvert                  No
#
# [3 rows x 33 columns]

# %% [markdown]
# ### 2.3: Selecting equal sized groups from block1 and block2
#
# **Randomly** select an equal number of students from each of `block1` and `block2` and store them in `control1` and `control2`.  We will combine both groups to make the full control group:

# %%
control1 = block1.sample(n =10)

# Show a few rows to check if the control group has the data we expect:
control1.sample(n=5)
# Out:
#       Name                          Major School Year    Phone  \
# 45    Cara           Chemical Engineering       Other  Android
# 58     Ben                      Math + CS    Freshman   iPhone
# 70  Claude                   Communicaton      Junior  Android
# 55     Ben                         any CS   Sophomore  Android
# 72   Shawn  Computer Science + Statistics    Freshman   iPhone
#
#                   Computer  Holes in a Straw  Has Dogs  Has Cats  Has Fish  \
# 45  Windows-based computer               NaN         1         1         0
# 58  Windows-based computer               1.0         0         1         0
# 70  Windows-based computer               1.0         0         0         0
# 55    Linux-based computer              20.0         0         0         0
# 72  Windows-based computer               1.0         1         0         0
#
#     Has Chickens  ...  Programmed before?  \
# 45             0  ...                 Yes
# 58             0  ...                 Yes
# 70             0  ...                  No
# 55             0  ...                 Yes
# 72             0  ...                 Yes
#
#                                     Python Background  Statistics Courses  \
# 45  Some Python -- I have had one class or written...                   2
# 58  Some Python -- I have had one class or written...                   2
# 70  No programming background -- is Python Taylor ...                   1
# 55  No Python, but I've done some programming in o...                   2
# 72  No Python, but I've done some programming in o...                   0
#
#     Hours Studying Siblings Hours of Sleep  Shoes Owned  \
# 45             4.0        1            8.0           10
# 58             1.5        1            8.0           30
# 70             2.0        1            6.0            4
# 55             3.0        0            8.0            2
# 72             2.0        1            7.0           10
#
#     People Texted Yesterday  Personality  Pineapple on Pizza
# 45                        7    Introvert                  No
# 58                        7    Extrovert                  No
# 70                        6    Introvert                  No
# 55                        0    Introvert                  No
# 72                        7    Extrovert                  No
#
# [5 rows x 33 columns]

# %%
control2 = block2.sample(n=10)



# Show a few rows to check if the control group has the data we expect:
control2.sample(n=3)
# Out:
#              Name                                    Major School Year  \
# 66         Yousef  Econometrics and Quantitative Economics    Freshman
# 19           Rutu                        Computer Engineer      Senior
# 73  Sabah Hussain                   Industrial engineering      Junior
#
#      Phone                 Computer  Holes in a Straw  Has Dogs  Has Cats  \
# 66  iPhone  Mac OS X-based computer               1.0         0         1
# 19  iPhone  Mac OS X-based computer               1.0         0         0
# 73  iPhone  Mac OS X-based computer               2.0         0         0
#
#     Has Fish  Has Chickens  ...  Programmed before?  \
# 66         0             0  ...                  No
# 19         0             0  ...                 Yes
# 73         0             0  ...                 Yes
#
#                                     Python Background  Statistics Courses  \
# 66  No programming background -- is Python Taylor ...                   1
# 19  Significant -- I am a wizard when it comes to ...                   0
# 73  No programming background -- is Python Taylor ...                   3
#
#     Hours Studying Siblings Hours of Sleep  Shoes Owned  \
# 66             4.0        7            7.0           10
# 19             3.0        2            7.0           15
# 73             3.0        2            7.0            8
#
#     People Texted Yesterday  Personality  Pineapple on Pizza
# 66                        2    Introvert                  No
# 19                       10    Extrovert                 Yes
# 73                        3    Introvert                  No
#
# [3 rows x 33 columns]

# %% [markdown]
# #### 2.4. [CHALLENGE!] -- Combine the two sub-groups into a single control group
#
# Use the following code to merge the contents of `control1` and `control2` together into one large group called `control`.  To do this, you will need to use the `pd.concat` command that you can **find on your cheat sheet**.

# %%
control = pd.concat([control1,control2])



# Show the full control group (it should have 20 rows, mixed number of siblings)
control
# Out:
#               Name                                    Major School Year  \
# 55             Ben                                   any CS   Sophomore
# 58             Ben                                Math + CS    Freshman
# 6          Prudhvi                        Actuarial Science      Junior
# 72           Shawn            Computer Science + Statistics    Freshman
# 45            Cara                     Chemical Engineering       Other
# 26         Sabrina                           CS + Chemistry   Sophomore
# 12           Grace                                      NaN   Sophomore
# 70          Claude                             Communicaton      Junior
# 13          Daniel                               Statistics    Freshman
# 74          Ishaan                         Computer Science      Senior
# 73   Sabah Hussain                   Industrial engineering      Junior
# 31           Ralph     Econometrics, Informational Sciences   Sophomore
# 84          Feliks                               Statistics      Junior
# 53            Vada                              Advertising   Sophomore
# 68         Cameron                          Film Production      Junior
# 66          Yousef  Econometrics and Quantitative Economics    Freshman
# 61           Vivek                                Economics      Senior
# 67  Jose Hernandez                        Political Science   Sophomore
# 51          Xavier                    Environmental Science      Junior
# 19            Rutu                        Computer Engineer      Senior
#
#       Phone                 Computer  Holes in a Straw  Has Dogs  Has Cats  \
# 55  Android     Linux-based computer              20.0         0         0
# 58   iPhone   Windows-based computer               1.0         0         1
# 6    iPhone                    Other               2.0         0         0
# 72   iPhone   Windows-based computer               1.0         1         0
# 45  Android   Windows-based computer               NaN         1         1
# 26  Android   Windows-based computer               1.0         0         0
# 12   iPhone  Mac OS X-based computer               1.0         0         0
# 70  Android   Windows-based computer               1.0         0         0
# 13   iPhone   Windows-based computer               2.0         0         1
# 74   iPhone  Mac OS X-based computer               1.0         1         1
# 73   iPhone  Mac OS X-based computer               2.0         0         0
# 31   iPhone  Mac OS X-based computer               1.0         0         0
# 84   iPhone   Windows-based computer               1.0         1         0
# 53   iPhone  Mac OS X-based computer               1.0         0         1
# 68   iPhone  Mac OS X-based computer               1.0         1         0
# 66   iPhone  Mac OS X-based computer               1.0         0         1
# 61   iPhone  Mac OS X-based computer               2.0         1         0
# 67   iPhone  Mac OS X-based computer               2.0         0         0
# 51   iPhone  Mac OS X-based computer               1.0         1         0
# 19   iPhone  Mac OS X-based computer               1.0         0         0
#
#     Has Fish  Has Chickens  ...  Programmed before?  \
# 55         0             0  ...                 Yes
# 58         0             0  ...                 Yes
# 6          0             0  ...                 Yes
# 72         0             0  ...                 Yes
# 45         0             0  ...                 Yes
# 26         0             0  ...                 Yes
# 12         0             0  ...                  No
# 70         0             0  ...                  No
# 13         0             0  ...                  No
# 74         0             0  ...                 Yes
# 73         0             0  ...                 Yes
# 31         0             0  ...                 Yes
# 84         0             0  ...                 Yes
# 53         0             0  ...                  No
# 68         0             0  ...                 Yes
# 66         0             0  ...                  No
# 61         0             0  ...                 Yes
# 67         0             0  ...                  No
# 51         0             0  ...                 Yes
# 19         0             0  ...                 Yes
#
#                                     Python Background  Statistics Courses  \
# 55  No Python, but I've done some programming in o...                   2
# 58  Some Python -- I have had one class or written...                   2
# 6   No Python, but I've done some programming in o...                   3
# 72  No Python, but I've done some programming in o...                   0
# 45  Some Python -- I have had one class or written...                   2
# 26  No Python, but I've done some programming in o...                   1
# 12  No programming background -- is Python Taylor ...                   1
# 70  No programming background -- is Python Taylor ...                   1
# 13  No programming background -- is Python Taylor ...                   0
# 74  Some Python -- I have had one class or written...                   1
# 73  No programming background -- is Python Taylor ...                   3
# 31  Some Python -- I have had one class or written...                   1
# 84  Some Python -- I have had one class or written...                   2
# 53  No programming background -- is Python Taylor ...                   1
# 68  Some Python -- I have had one class or written...                   2
# 66  No programming background -- is Python Taylor ...                   1
# 61  Some Python -- I have had one class or written...                   6
# 67  No programming background -- is Python Taylor ...                   1
# 51  Some Python -- I have had one class or written...                   1
# 19  Significant -- I am a wizard when it comes to ...                   0
#
#     Hours Studying Siblings Hours of Sleep  Shoes Owned  \
# 55             3.0        0            8.0            2
# 58             1.5        1            8.0           30
# 6              4.0        1            7.0            3
# 72             2.0        1            7.0           10
# 45             4.0        1            8.0           10
# 26             6.0        1            7.0           16
# 12             4.0        1            7.0            8
# 70             2.0        1            6.0            4
# 13             1.0        1            9.0            3
# 74             4.0        1            7.0            9
# 73             3.0        2            7.0            8
# 31             3.0        2            6.0            7
# 84             3.5        3            8.3            4
# 53             2.0        2            8.0           15
# 68             3.0        2            8.0            5
# 66             4.0        7            7.0           10
# 61            12.0        2            8.0            6
# 67             1.0        3            7.5           12
# 51             4.0        2            5.0            8
# 19             3.0        2            7.0           15
#
#     People Texted Yesterday  Personality  Pineapple on Pizza
# 55                        0    Introvert                  No
# 58                        7    Extrovert                  No
# 6                         5    Extrovert                 Yes
# 72                        7    Extrovert                  No
# 45                        7    Introvert                  No
# 26                       13    Introvert                 Yes
# 12                        5    Introvert                  No
# 70                        6    Introvert                  No
# 13                        5    Extrovert                  No
# 74                       22    Introvert                 Yes
# 73                        3    Introvert                  No
# 31                        4    Extrovert                  No
# 84                        8    Introvert                  No
# 53                       20    Extrovert                 Yes
# 68                        6    Extrovert                  No
# 66                        2    Introvert                  No
# 61                       25    Extrovert                  No
# 67                        7    Introvert                  No
# 51                        5    Extrovert                  No
# 19                       10    Extrovert                 Yes
#
# [20 rows x 33 columns]

# %%
## == TEST CASES for Puzzle 2 ==
# - This read-only cell contains test cases for your previous cells.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check you previous cell, make changes, and RE-RUN your code and then this cell.

assert( len(control) == 20 ), "Your control group must only have 20 courses in it."
assert( len(control[control.Siblings < 2] ) == 10 ), "Your control group must only have 10 people with 0-1 siblings in it."
assert( len(control[control.Siblings >= 2] ) == 10 ), "Your control group must only have 10 people with 2+ siblings in it."


## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:

tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Submit Your Work!
#
# Make sure to **Save and Checkpoint** your notebook, exit Jupyter, and submit your work! :)
